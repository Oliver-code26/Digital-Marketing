# %% [markdown]
# Online Advertising Performance Data

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# My objective is to create two charts for the two campaigns, a pie chart showcasing what was more engaging out of Banners, Displays and Clicks. Followed by a line chart showcasing the campaigns and their progress of customer engagment within three months.
#
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# I have asked Copliot to generate a bar chart and three individual pie chart for each Campaign.
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# Upon recieving both charts, I have seen that the ROAS (Return on ad sepend) has taken up most of the charts. This is fine if I was researching the finance side of the Campaigns, however in terms of engagment which matches with my objective, Campaign 1 has more Conversion Rates and CPC (Cost per Click) than Campaign 2 and 3.
#
# ## Additional Comments
#
# This dataset is being used from Kaggle and created/owned by N. Aniruddhan.
# Thanks to Vasi P. And Rory P. For assissting me in cleaning the code.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\PC\\Documents\\vs_code\\digital_marketing\\Digital-Marketing\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
#os.chdir(os.path.dirname(os.path.abspath("online_advertising_performance_data.csv")))
#print("You set a new current directory")

import pandas as pd

csv_path = "../online_advertising_performance_data.csv"
df = pd.read_csv(csv_path)

df.head()
# Out:
#    month  day campaign_number user_engagement     banner placement  displays  \
# 0  April    1          camp 1            High  160 x 600       abc         4
# 1  April    1          camp 1            High  160 x 600       def     20170
# 2  April    1          camp 1            High  160 x 600       ghi     14701
# 3  April    1          camp 1            High  160 x 600       mno    171259
# 4  April    1          camp 1             Low  160 x 600       def       552
#
#        cost  clicks   revenue  post_click_conversions  \
# 0    0.0060       0    0.0000                       0
# 1   26.7824     158   28.9717                      23
# 2   27.6304     158   28.9771                      78
# 3  216.8750    1796  329.4518                     617
# 4    0.0670       1    0.1834                       0
#
#    post_click_sales_amount  Unnamed: 12  Unnamed: 13
# 0                   0.0000          NaN          NaN
# 1                1972.4602          NaN          NaN
# ...

# %% [markdown]
# Confirm the new current directory

# %%
#current_dir = os.getcwd()
#current_dir
print(df.head)
# Out:
# <bound method NDFrame.head of        month  day campaign_number user_engagement     banner placement  \
# 0      April    1          camp 1            High  160 x 600       abc
# 1      April    1          camp 1            High  160 x 600       def
# 2      April    1          camp 1            High  160 x 600       ghi
# 3      April    1          camp 1            High  160 x 600       mno
# 4      April    1          camp 1             Low  160 x 600       def
# ...      ...  ...             ...             ...        ...       ...
# 15403  April    1          camp 1             Low  160 x 600       ghi
# 15404  April    1          camp 1             Low  160 x 600       mno
# 15405   June   29          camp 1            High  800 x 250       ghi
# 15406   June   29          camp 1            High  800 x 250       mno
# 15407   June   29          camp 3            High  240 x 400       def
#
#        displays      cost  clicks   revenue  post_click_conversions  \
# ...

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %%
import matplotlib.pyplot as plt

campaign_summary.plot(
    kind='bar',
    figsize=(10, 5),
    title='Campaign Summary Metrics',
    ylabel='Average Value',
    xlabel='Campaign Number'
)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# In the Campaign Summary Metrics we see ROAS has surpassed the other values. from an engagment perspective we see that Camp 1 has the highest Conversion rate alongside CPC.
#
# I have also noticed that in Camp 2 the CTR is higher than either of the other campaigns. Also in Camp 3 the CPC is higher than the Conversion Rate.

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %%
import matplotlib.pyplot as plt

for campaign in campaign_summary.index:
    values = campaign_summary.loc[campaign].values
    labels = campaign_summary.columns
    sizes = values / values.sum() * 100

    plt.figure(figsize=(6, 6))
    plt.pie(
        sizes,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90,
        wedgeprops={'edgecolor': 'white'}
    )
    plt.title(f'Pie Chart for {campaign}')
    plt.axis('equal')
    plt.show()

# %% [markdown]
# ---

# %%
import IPython.display

IPython.display.Image(filename = 'Images/Bar_Chart_Summary_Metrics.png')
#IPython.display.Image(filename = 'Images/Pie_chart_Camp1.png')
#IPython.display.Image(filename = 'Images/Pie_chart_Camp2.png')

# %% [markdown]
# After asking ChatGPT to remove the ROAS because not only was that taking up most of the visual data, it wasn't needed as I'm measuring engagment.
#
# We see that Campain 1 has the most conversion rate, this would mean that this is a success with how many visitors bacame cuustomers. I wonder how much time Campaign 1 was out for as we see Campaign 3 is slighlty rising above Campaign 2, which might be more belivable in interaction/engagment as we havent got a timeline in this chart.

# %%
IPython.display.Image(filename = 'Images/Pie_chart_Camp1.png')

# %% [markdown]
# In the pie charts above it's obvious Campaign 1 was the most successful but as I mentioned earlier it would seem the other campaigns might be more realistic results if you consider looking for a flow of engagment.
#
# Upon looking through the dataset I am supposed to be looking at three months worth of data (April-June) it is unclear if I'm looking at three months in a chart or just April.

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
# Out:
#   Cell In[2], line 5
#     except Exception as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 2
